# %%
import requests

response = requests.post(
    "http://10.20.31.1:11434/api/chat",
    json={
        "model": "deepseek-r1",
        "messages": [{"role": "user", "content": "Describe to me some really detailed star wars lore!"}],
        "stream": False  # Set to True for streaming
    }
)
print(response.json()["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 11
#       1 import requests
#       3 response = requests.post(
#       4     "http://10.20.31.1:11434/api/chat",
#       5     json={
#    (...)
#       9     }
#      10 )
# ---> 11 print(response.json()["message"]["content"])
#
# KeyError: 'message'

# %%
response = requests.post(
    "http://10.20.31.1:11434/api/chat",
    json={
        "model": "llama4",
        "messages": [{"role": "user", "content": "How much do you know about aincient chinese medicine? Tell me about what is real from there and backed by science, and what is fake. Do so in an informative and brief way. I am a 23 year old male with few to no health issues."}],
        "stream": False  # Set to True for streaming
    }
)
print(response.json()["message"]["content"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 9
#       1 response = requests.post(
#       2     "http://10.20.31.1:11434/api/chat",
#       3     json={
#    (...)
#       7     }
#       8 )
# ----> 9 print(response.json()["message"]["content"])
#
# KeyError: 'message'
